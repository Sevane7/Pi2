# %% [markdown]
# # Backtests de la stratégie covariance based

# %%
import pandas as pd
import os

os.chdir("..\..")
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# <>:4: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\sevan\AppData\Local\Temp\ipykernel_3776\1548887590.py:4: SyntaxWarning: invalid escape sequence '\.'
#   os.chdir("..\..")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\sevan\\OneDrive - De Vinci\\A4\\Pi2'

# %%
metrics_path = r"Data\Forecasting\metrics"

metrics = pd.DataFrame(None)

for file in os.listdir(metrics_path):
    if file.endswith(".xlsx"):
        file_path = os.path.join(metrics_path, file)
        metrics = pd.read_excel(file_path)

# %%
metrics.sort_values(by="Hit Ratio", ascending=False)
# Out:
#       Size Matrix   Asset Timeframe Hurst Frequence  Horizon  \
# 2928           40     ETH      1min           15min       11
# 6404           50      GS      1min              6h        7
# 6414           50      GS      1min             12h        7
# 6374           50      GS      1min           30min        7
# 6384           50      GS      1min              1h        7
# ...           ...     ...       ...             ...      ...
# 2276          100  UST10Y      1min           15min        9
# 12435          70  UST10Y      1min              6h        8
# 12425          70  UST10Y      1min              3h        8
# 2322          100  UST10Y      1min             12h        5
# 2326          100  UST10Y      1min             12h        9
#
#                      From                  To  Hit Ratio           MSE
# 2928  2024-12-19 00:01:00 2024-12-19 00:27:00   0.846154  3.553571e-05
# 6404  2024-12-09 17:51:00 2024-12-09 18:32:00   0.775000  1.421429e-06
# ...
